# %% [markdown]
# # Importing the data

# %%
import pandas as pd
import numpy as np

# %%
qualtrics_data = pd.read_csv("SurveyData.csv")
logging_data = pd.read_csv("LoggingData.csv")

# %% [markdown]
# # Quick data analysis

# %%
qualtrics_users = qualtrics_data["Please enter your Mturk ID.  (We need this to pay you accordingly)"].unique()
logging_users = logging_data["mTurk ID"].unique()

not_in_log = [user for user in qualtrics_users if user not in logging_users]
not_in_qualt = [user for user in logging_users if user not in qualtrics_users]

# %%
not_in_qualt
# Out:
# []

# %%
not_in_log
# Out:
# []

# %% [markdown]
# # Fixing the data

# %%
qualtrics_data = qualtrics_data.set_index("Please enter your Mturk ID.  (We need this to pay you accordingly)")
qualtrics_data = qualtrics_data.drop(not_in_log, axis=0).reset_index()

# %%
qualtrics_data
# Out:
#    Please enter your Mturk ID.  (We need this to pay you accordingly)  \
# 0                                      A1ROEDVMTO9Y3X
# 1                                      A2ESE3IBTNAEB7
# 2                                      A30KYQGABO7JER
# 3                                      A2R9OK4M877ZCC
# 4                                      A1V2H0UF94ATWY
# 5                                      A1YFVXP4A1CXSF
# 6                                      A36Z98LFRR041Q
# 7                                      A3PDHDQZZKCTT5
# 8                                       A5X1KZ9CCHREK
# 9                                       AJ7MWBQFNH3E4
# 10                                     A16SAB417Y96G4
# 11                                     A22A52DRIIEV6K
# 12                                     A2E3TO92MCQ9XU
# 13                                     A2EKR2ZFO10VMV
# 14                                     A2J9U65SKT4TJW
# 15                                     A2Z70GL7HTFFQR
# 16                                      A2ZJAEL03VTZ8
# 17                                     A3NMQ3019X6YE0
# 18                                      A6WXIKRYMXNIN
# 19                                     A160HFSRDNT91E
# 20                                     A1Q68M0X4YXHKH
# 21                                     A1VXDD6BFF97OF
# 22                                     A219Y0MX694TM2
# 23                                     A23K7MLCDZPV0D
# 24                                     A2KHMKJUVDMK1N
# 25                                     A31XT6RPLN6359
# 26                                     A3IMB1JAMHP1KK
# 27                                     A3L0DCUXI7X3A9
# 28                                     A1AF25FCVKC87X
# 29                                      A9ZCY6FLUCIU1
# 30                                     A1SNC8UL8YFRH5
# 31                                     A3TPW4JUUJDUFI
# 32                                     A17LF7GCAFYMSL
# 33                                     A1L07RXTK5X5MG
# 34                                     A1YX741QQSMKPS
# 35                                     A39GADIK8RLMVC
# 36                                     A3BXT78QXFC6F3
#
#           Start Date          End Date Response Type       IP Address  \
# 0    6/11/2019 19:30  10/11/2019 12:32    IP Address     67.8.193.168
# 1   10/11/2019 15:54  10/11/2019 16:18    IP Address    173.215.15.44
# 2    9/11/2019 23:59   10/11/2019 1:23    IP Address      67.21.32.80
# 3   10/11/2019 17:50  10/11/2019 18:42    IP Address    66.170.205.17
# 4   10/11/2019 12:04  10/11/2019 12:49    IP Address    73.236.40.189
# 5   10/11/2019 12:27  10/11/2019 13:54    IP Address    172.58.78.183
# 6    10/11/2019 9:48  10/11/2019 10:34    IP Address   208.126.51.247
# 7   10/11/2019 20:02  10/11/2019 20:41    IP Address    99.164.34.236
# 8    10/11/2019 5:16   10/11/2019 5:57    IP Address    122.3.232.202
# 9    10/11/2019 6:48   10/11/2019 8:19    IP Address    69.125.97.156
# 10  11/11/2019 17:01  11/11/2019 18:10    IP Address   67.177.247.141
# 11  11/11/2019 12:35  11/11/2019 14:12    IP Address   104.236.55.136
# 12  11/11/2019 17:41  11/11/2019 18:00    IP Address    50.46.135.248
# 13  11/11/2019 14:50  11/11/2019 15:10    IP Address     108.66.4.224
# 14  11/11/2019 13:47  11/11/2019 14:20    IP Address    69.244.173.44
# 15   11/11/2019 9:48  11/11/2019 10:33    IP Address   104.131.19.173
# 16   11/11/2019 9:11  11/11/2019 10:23    IP Address     192.67.88.14
# 17  11/11/2019 16:35  11/11/2019 16:59    IP Address   192.209.17.137
# 18  11/11/2019 14:32  11/11/2019 15:09    IP Address     73.26.61.159
# 19   12/11/2019 4:41   12/11/2019 5:02    IP Address     92.38.148.53
# 20  12/11/2019 10:22  12/11/2019 10:48    IP Address  162.155.193.105
# 21   12/11/2019 6:42   12/11/2019 7:26    IP Address    73.187.88.148
# 22  12/11/2019 11:40  12/11/2019 12:01    IP Address     73.221.29.39
# 23   12/11/2019 8:33  12/11/2019 10:11    IP Address    107.77.228.67
# 24  12/11/2019 12:25  12/11/2019 12:43    IP Address   108.12.238.177
# 25   12/11/2019 5:14   12/11/2019 6:10    IP Address      73.230.7.68
# 26   12/11/2019 4:42   12/11/2019 5:09    IP Address     73.230.55.35
# 27   12/11/2019 5:24   12/11/2019 6:02    IP Address    73.194.199.39
# 28  12/11/2019 15:56  12/11/2019 16:17    IP Address     24.253.16.20
# 29  12/11/2019 17:45  12/11/2019 18:18    IP Address   67.254.210.204
# 30  12/11/2019 18:31  12/11/2019 18:57    IP Address    108.51.169.16
# 31  12/11/2019 20:35  12/11/2019 21:27    IP Address    50.239.137.75
# 32   13/11/2019 2:12   13/11/2019 3:43    IP Address     73.19.77.184
# 33   13/11/2019 6:24   13/11/2019 7:34    IP Address     45.4.197.224
# 34  12/11/2019 12:36  12/11/2019 13:50    IP Address   108.253.190.88
# 35  12/11/2019 12:04  12/11/2019 12:39    IP Address   174.242.73.160
# 36  12/11/2019 11:57  12/11/2019 12:28    IP Address   35.136.254.105
#
#     Progress  Duration (in seconds)  Finished     Recorded Date  \
# 0        100                 320525      True  10/11/2019 12:32
# 1        100                   1467      True  10/11/2019 16:18
# 2        100                   5083      True   10/11/2019 1:23
# 3        100                   3083      True  10/11/2019 18:42
# 4        100                   2713      True  10/11/2019 12:49
# 5        100                   5244      True  10/11/2019 13:54
# 6        100                   2762      True  10/11/2019 10:34
# 7        100                   2376      True  10/11/2019 20:41
# 8        100                   2448      True   10/11/2019 5:57
# 9        100                   5413      True   10/11/2019 8:19
# 10       100                   4103      True  11/11/2019 18:10
# 11       100                   5775      True  11/11/2019 14:12
# 12       100                   1101      True  11/11/2019 18:00
# 13       100                   1186      True  11/11/2019 15:10
# 14       100                   1969      True  11/11/2019 14:20
# 15       100                   2700      True  11/11/2019 10:33
# 16       100                   4304      True  11/11/2019 10:23
# 17       100                   1447      True  11/11/2019 16:59
# 18       100                   2234      True  11/11/2019 15:09
# 19       100                   1252      True   12/11/2019 5:02
# 20        94                   1586     False  13/11/2019 12:28
# 21       100                   2676      True   12/11/2019 7:26
# 22       100                   1287      True  12/11/2019 12:01
# 23       100                   5859      True  12/11/2019 10:11
# 24       100                   1098      True  12/11/2019 12:43
# 25       100                   3338      True   12/11/2019 6:10
# 26       100                   1632      True   12/11/2019 5:09
# 27       100                   2281      True   12/11/2019 6:02
# 28       100                   1265      True  12/11/2019 16:17
# 29       100                   1976      True  12/11/2019 18:18
# 30       100                   1587      True  12/11/2019 18:57
# 31       100                   3111      True  12/11/2019 21:27
# 32       100                   5477      True   13/11/2019 3:43
# 33       100                   4220      True   13/11/2019 7:34
# 34       100                   4453      True  12/11/2019 13:50
# 35       100                   2071      True  12/11/2019 12:39
# 36        94                   1880     False  13/11/2019 12:52
#
#           Response ID  ...  \
# 0   R_332t7SbrnIe02NV  ...
# 1   R_1Nq9sQE3mJMn78I  ...
# 2   R_1GH989iefoCEdMj  ...
# 3   R_3oG7EYTWbBw0PZu  ...
# 4   R_1Oy8cI4B6quPY8h  ...
# 5   R_3nHF3yjRe6e8kjm  ...
# 6   R_2U4bmf0iO6tR9zg  ...
# 7   R_3n0dDOIU3Xn2HG6  ...
# 8   R_11hLl3wqVNR5ppC  ...
# 9   R_1C0ZlTAQcz6B9Bf  ...
# 10  R_2ypdWTmbed4ZoNj  ...
# 11  R_24pmAyNdWhHSP9L  ...
# 12  R_sSw5SNYOmWMjqlX  ...
# 13  R_3luEZdS4iN5QRCz  ...
# 14  R_2EmikmLgPBLs27U  ...
# 15  R_3el9yyAV9h0fDF5  ...
# 16  R_2bPlO8fsTZxtjqh  ...
# 17  R_3MaPq23mIMXtdC3  ...
# 18  R_1GBtdSiA5Me7JPb  ...
# 19  R_3iPAaH5ZR9tzlTk  ...
# 20  R_2uqEXFFbQSh4s5m  ...
# 21  R_2X1gTOJLNhz59rT  ...
# 22  R_3HUeH6sCS0Py2fP  ...
# 23  R_3is55pVcFYDJwVk  ...
# 24  R_1odtHfAM1gKx07D  ...
# 25  R_xl5Eaq3MtynAnrH  ...
# 26  R_1oBbzgHRyEIC396  ...
# 27  R_3n3eYfbupnde9qQ  ...
# 28  R_cvZhkibQXpNVoS5  ...
# 29  R_ezK1ucchtTxe6Ah  ...
# 30  R_1JXcplUSyYJFM1w  ...
# 31  R_2zBcLrH2d7ui7Zk  ...
# 32  R_bjSJ6CjNUa7IcN3  ...
# 33  R_RPiAziFdo2EtNUR  ...
# 34  R_1FledX1oGlwmKR9  ...
# 35  R_3kcPMtrCnL4o5rk  ...
# 36  R_W0Zqa8ie33NtquJ  ...
#
#     Select your gender (You may skip this question if you do not wish to answer)  \
# 0                                              Female
# 1                                              Female
# 2                                              Female
# 3                                                Male
# 4                                                Male
# 5                                              Female
# 6                                              Female
# 7                                              Female
# 8                                                Male
# 9                                              Female
# 10                                               Male
# 11                                             Female
# 12                                               Male
# 13                                             Female
# 14                                             Female
# 15                                               Male
# 16                                             Female
# 17                                             Female
# 18                                               Male
# 19                                               Male
# 20                                               Male
# 21                                             Female
# 22                                             Female
# 23                                             Female
# 24                                               Male
# 25                                             Female
# 26                                               Male
# 27                                               Male
# 28                                               Male
# 29                                             Female
# 30                                               Male
# 31                                               Male
# 32                                               Male
# 33                                             Female
# 34                                               Male
# 35                                               Male
# 36                                             Female
#
#     Select your highest attained education level (You may skip this question if you do not wish to answer)  \
# 0        High School graduate (Diploma or equivalent)
# 1        High School graduate (Diploma or equivalent)
# 2                                 Bachelorâ€™s Degree
# 3                                 Bachelorâ€™s Degree
# 4        High School graduate (Diploma or equivalent)
# 5        High School graduate (Diploma or equivalent)
# 6        High School graduate (Diploma or equivalent)
# 7                                 Bachelorâ€™s Degree
# 8        High School graduate (Diploma or equivalent)
# 9                                 Bachelorâ€™s Degree
# 10                                Bachelorâ€™s Degree
# 11                                Bachelorâ€™s Degree
# 12                                Bachelorâ€™s Degree
# 13                                Bachelorâ€™s Degree
# 14       High School graduate (Diploma or equivalent)
# 15       High School graduate (Diploma or equivalent)
# 16       High School graduate (Diploma or equivalent)
# 17       High School graduate (Diploma or equivalent)
# 18                                Bachelorâ€™s Degree
# 19                        Masterâ€™s Degree or higher
# 20                                Bachelorâ€™s Degree
# 21                                Bachelorâ€™s Degree
# 22       High School graduate (Diploma or equivalent)
# 23                        Masterâ€™s Degree or higher
# 24                                Bachelorâ€™s Degree
# 25       High School graduate (Diploma or equivalent)
# 26       High School graduate (Diploma or equivalent)
# 27                                Bachelorâ€™s Degree
# 28                                Bachelorâ€™s Degree
# 29                                Bachelorâ€™s Degree
# 30       High School graduate (Diploma or equivalent)
# 31                                Bachelorâ€™s Degree
# 32                                Bachelorâ€™s Degree
# 33                                Bachelorâ€™s Degree
# 34                                Bachelorâ€™s Degree
# 35                                Bachelorâ€™s Degree
# 36       High School graduate (Diploma or equivalent)
#
#     Timing - First Click  Timing - Last Click  Timing - Page Submit  \
# 0                    NaN                  NaN                   NaN
# 1                    NaN                  NaN                   NaN
# 2                    NaN                  NaN                   NaN
# 3                    NaN                  NaN                   NaN
# 4                    NaN                  NaN                   NaN
# 5                    NaN                  NaN                   NaN
# 6                    NaN                  NaN                   NaN
# 7                    NaN                  NaN                   NaN
# 8                    NaN                  NaN                   NaN
# 9                    NaN                  NaN                   NaN
# 10                   NaN                  NaN                   NaN
# 11                   NaN                  NaN                   NaN
# 12                   NaN                  NaN                   NaN
# 13                   NaN                  NaN                   NaN
# 14                   NaN                  NaN                   NaN
# 15                   NaN                  NaN                   NaN
# 16                   NaN                  NaN                   NaN
# 17                   NaN                  NaN                   NaN
# 18                   NaN                  NaN                   NaN
# 19                   NaN                  NaN                   NaN
# 20                   NaN                  NaN                   NaN
# 21                   NaN                  NaN                   NaN
# 22                   NaN                  NaN                   NaN
# 23                   NaN                  NaN                   NaN
# 24                   NaN                  NaN                   NaN
# 25                   NaN                  NaN                   NaN
# 26                   NaN                  NaN                   NaN
# 27                   NaN                  NaN                   NaN
# 28                   NaN                  NaN                   NaN
# 29                   NaN                  NaN                   NaN
# 30                   NaN                  NaN                   NaN
# 31                   NaN                  NaN                   NaN
# 32                   NaN                  NaN                   NaN
# 33                   NaN                  NaN                   NaN
# 34                   NaN                  NaN                   NaN
# 35                   NaN                  NaN                   NaN
# 36                   NaN                  NaN                   NaN
#
#     Timing - Click Count RandomID hidePrev           userID  \
# 0                    NaN   500970        0   A1ROEDVMTO9Y3X
# 1                    NaN   132056        0   A2ESE3IBTNAEB7
# 2                    NaN   718358        0   A30KYQGABO7JER
# 3                    NaN   283031        0   A2R9OK4M877ZCC
# 4                    NaN   111129        0   A1V2H0UF94ATWY
# 5                    NaN   787164        0   A1YFVXP4A1CXSF
# 6                    NaN   857148        0   A36Z98LFRR041Q
# 7                    NaN   733346        0   A3PDHDQZZKCTT5
# 8                    NaN   104883        0    A5X1KZ9CCHREK
# 9                    NaN   632639        0    AJ7MWBQFNH3E4
# 10                   NaN   122266        0   A16SAB417Y96G4
# 11                   NaN   958695        0   A22A52DRIIEV6K
# 12                   NaN   906100        0   A2E3TO92MCQ9XU
# 13                   NaN   599056        0   A2EKR2ZFO10VMV
# 14                   NaN   749275        0   A2J9U65SKT4TJW
# 15                   NaN   344917        0   A2Z70GL7HTFFQR
# 16                   NaN   393505        0    A2ZJAEL03VTZ8
# 17                   NaN   354291        0   A3NMQ3019X6YE0
# 18                   NaN   188118        0    A6WXIKRYMXNIN
# 19                   NaN   176878        0   A160HFSRDNT91E
# 20                   NaN   956499        0  A1Q68M0X4YXHKH
# 21                   NaN   766764        0   A1VXDD6BFF97OF
# 22                   NaN   284882        0   A219Y0MX694TM2
# 23                   NaN   572498        0   A23K7MLCDZPV0D
# 24                   NaN   612407        0   A2KHMKJUVDMK1N
# 25                   NaN   200282        0   A31XT6RPLN6359
# 26                   NaN   599874        0   A3IMB1JAMHP1KK
# 27                   NaN   847762        0   A3L0DCUXI7X3A9
# 28                   NaN   245637        0   A1AF25FCVKC87X
# 29                   NaN   135260        0    A9ZCY6FLUCIU1
# 30                   NaN   927465        0   A1SNC8UL8YFRH5
# 31                   NaN   866435        0   A3TPW4JUUJDUFI
# 32                   NaN   964019        0   A17LF7GCAFYMSL
# 33                   NaN   958397        0   A1L07RXTK5X5MG
# 34                   NaN   780839        0   A1YX741QQSMKPS
# 35                   NaN   228563        0   A39GADIK8RLMVC
# 36                   NaN   586092        0   A3BXT78QXFC6F3
#
#    Create New Field or Choose From Dropdown...
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# 30                                         NaN
# 31                                         NaN
# 32                                         NaN
# 33                                         NaN
# 34                                         NaN
# 35                                         NaN
# 36                                         NaN
#
# [37 rows x 95 columns]

# %% [markdown]
# # Transforming the data

# %%
columns = list(qualtrics_data.columns)
important_cols = []

columns[0] = "Mturk_ID"
important_cols.append(columns[0])

nb_trials = 8
questions_per_trial = 6
trial_1_code_id = 28

curr_trial = 1
for i in range(nb_trials):
    start_id = trial_1_code_id + ((curr_trial - 1) * questions_per_trial)
    
    columns[start_id] = '{}_trial--code'.format(curr_trial)
    columns[start_id + 1] = 'guidance_{}'.format(curr_trial)
    columns[start_id + 2] = 'recover_{}'.format(curr_trial)
    columns[start_id + 3] = 'quick_{}'.format(curr_trial)
    columns[start_id + 4] = 'confusion_{}'.format(curr_trial)
    columns[start_id + 5] = 'thinking_{}'.format(curr_trial)
    
    for y in range(questions_per_trial):
        important_cols.append(columns[start_id + y])
    
    curr_trial += 1
    
columns[columns.index(
    'Would you agree or disagree that - Interface A feels faster to use than Interface B'
)] = "a_faster_than_b"
important_cols.append("a_faster_than_b")

columns[columns.index(
    'Would you agree or disagree that - Interface B is easier to use than Interface A'
)] = "b_easier_than_a"
important_cols.append("b_easier_than_a")

columns[columns.index(
    'Would you agree or disagree that - For the same list of options, you prefer viewing fewer options at once with more scrolling than\n\nviewing more options at once with less scrolling?'
)] = "more_scrolling_than_more_options"
important_cols.append("more_scrolling_than_more_options")

columns[columns.index(
    'Would you agree or disagree that - Interface A is clearer than interface B'
)] = "a_clearer_than_b"
important_cols.append("a_clearer_than_b")

columns[columns.index(
    'Would you agree or disagree that - Interface A is more confusing than interface B'
)] = "a_more_confusing_than_b"
important_cols.append("a_more_confusing_than_b")

columns[columns.index(
    'Do you prefer interface A or B?'
)] = "prefer_a_or_b"
important_cols.append("prefer_a_or_b")


qualtrics_data.columns = columns

# %% [markdown]
# ## Numericalizing the agree-disagree statements

# %%
def numericalize(string):
    diction = {
        "Strongly Agree": 2,
        "Strongly agree": 2,
        "Agree": 1,
        "Neither agree nor disagree": 0,
        "Disagree": -1,
        "Strongly Disagree": -2,
        "Strongly disagree": -2,
    }
    
    return diction[string] if string in diction.keys() else string

qualtrics_import = qualtrics_data[important_cols].applymap(numericalize)

# %% [markdown]
# ## Create distinct tables for joining

# %%
transposed = qualtrics_import.T
transposed["index"] = transposed.index

question_tables = []

for i in range(1, nb_trials + 1):
    question_tables.append(
        transposed[
            transposed["index"].isin([
                "Mturk_ID".format(i), 
                "{}_trial--code".format(i),
                "guidance_{}".format(i),
                "recover_{}".format(i),
                "quick_{}".format(i),
                "confusion_{}".format(i),
                "thinking_{}".format(i),
            ])
        ].T
    )

# %% [markdown]
# ## Join the tables

# %%
logging_data["task nb"] = logging_data["task id"].apply(lambda x: x[0])

# %%
cols = list(logging_data.columns)
cols[1] = "Mturk_ID"
logging_data.columns = cols

# %%
final_df = None

for group, data in logging_data.groupby(["Mturk_ID", "task nb"]):
    qns_all = question_tables[int(group[1]) - 1]
    qns_user = qns_all[qns_all["Mturk_ID"] == group[0]]
    
    merged = pd.merge(data, qns_user, on="Mturk_ID")
    cols = list(merged.columns)
    cols[-1] = "thinking"
    cols[-2] = "confusion"
    cols[-3] = "quick"
    cols[-4] = "recover"
    cols[-5] = "guidance"
    cols[-6] = "trial_code"
    merged.columns = cols
    
    final_df = pd.concat([final_df, merged]) if final_df is not None else merged

# %%
final_df = final_df.reset_index()

# %%
uniform_cols = list(qualtrics_import.columns)[-6:]
uniform_cols.append("Mturk_ID")

with_final_questions = pd.merge(final_df, qualtrics_import[uniform_cols], on="Mturk_ID")

# %% [markdown]
# ## Multiply by -1 for inversed questions

# %%
inversed_cols = [
    'recover',
    'confusion',
    'b_easier_than_a',
    'a_more_confusing_than_b',
]

with_final_questions[inversed_cols] = with_final_questions[inversed_cols] * -1

# %% [markdown]
# # Export results

# %%
with_final_questions.to_csv("transfromed_data.csv")

# %%
transformed = pd.read_csv("transfromed_data.csv")
assert len(logging_data) == len(transformed), "Lengths don't match!"
